# %% [markdown]
# final exam
#
# 1. 5/4
# 2. ed
# 3. 50% t/f. mc, fill in blank
# 4. 50 % pymongo/,mongodb and sql
#
# resources:
#     course notes. slides
#     python docs. sqlachemy, psycopg2, pymongo, mongodb, etc.
#     cheat sheet 1 page
# topics on exam:
#     basic sql
#     aggregation
#     joins
#     database design
#     normalization
#     subqueries(*)
#     strings and arrays
#     dates and times
#     conditionals
#     window functions
#     aggregate functions as window function
#     explain and analyze
#     adding indexes
#     python+ postgres
#         * psycopg2
#         * sqlalchemy
#     mongodb (*) find
#     mongodb aggregation
#     mongodb with python
#     database design with mongo
#
# No graphdatabase
#
# study material
# any mongodb coding question will be through pymongo
# brighstpace collection of quiz questions
# homework 09 for mongodb related questions
# https://pgexercises.com/questions/basic/selectspecific.html
# https://mystery.knightlab.com/
